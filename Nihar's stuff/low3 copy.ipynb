# %% [markdown]
# ### Example, full version steel data, version 3 + weather data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from phik import resources, report
import phik

# from phik.report import plot_correlation_matrix

# replace this with your own file path in your own file system
path = "../data/sulatto_fulldata2025_version2.csv"
df = pd.read_csv(path, delimiter=";")
# Out:
# C:\Users\Nihar Buha\AppData\Local\Temp\ipykernel_21044\2829613844.py:12: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, delimiter=";")

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\Scripts\python.exe

# %%
# load the weather data that matches partially with our steel data (originally FMI)
df_weather = pd.read_csv("../tornio_weather.csv")

# %%
df.describe()
# Out:
#               Weight          Width         Seg No  \
# count  677815.000000  677815.000000  677815.000000
# mean    23864.551870    1388.799020      55.634902
# std      3581.849791     151.115179      32.787337
# min      6700.000000    1034.000000       1.000000
# 25%     23218.000000    1284.000000      28.000000
# 50%     23280.000000    1284.000000      55.000000
# 75%     25795.000000    1543.000000      83.000000
# max    123605.000000    1620.000000     511.000000
#
#        CCM.TD. Heat counter Value  CCM.TD. Temperature liquidus Value  \
# count               677299.000000                            677299.0
# mean                     4.230857                              1455.0
# std                      2.264734                                 0.0
# min                      1.000000                              1455.0
# 25%                      2.000000                              1455.0
# 50%                      4.000000                              1455.0
# 75%                      6.000000                              1455.0
# max                     10.000000                              1455.0
#
#        CCM.TD. Temperature liquidus Dynaphase Value  CCM.TD. Superheat Value  \
# count                                 677299.000000            677299.000000
# mean                                    1458.794001                37.868677
# std                                        1.703725                 8.310765
# min                                     1452.000000                -3.000000
# 25%                                     1458.000000                34.000000
# 50%                                     1459.000000                38.000000
# 75%                                     1460.000000                42.000000
# max                                     1461.000000               145.000000
#
#        CCM.TD. Temperature tundish Value  CCM.SEN. Immersion depth Value  \
# count                      677299.000000                   677299.000000
# mean                         1492.868677                      180.253312
# std                             8.310765                       14.401174
# min                          1452.000000                        0.000000
# 25%                          1489.000000                      170.000000
# 50%                          1493.000000                      182.000000
# 75%                          1497.000000                      190.000000
# max                          1600.000000                      204.000000
#
#        CCM.MD. Mold width Value  CCM.SLAB. Slab counter heat Value  \
# count             677299.000000                      674264.000000
# mean                1388.580491                           3.602762
# std                  151.113934                           1.830274
# min                 1034.000000                           1.000000
# 25%                 1284.000000                           2.000000
# 50%                 1284.000000                           4.000000
# 75%                 1543.000000                           5.000000
# max                 1620.000000                           9.000000
#
#        CCM.SLAB. Slab counter sequence Value  HeatNo_in_Cast         CastNo
# count                          674496.000000   677815.000000  671826.000000
# mean                               23.412446     3853.831222     175.767377
# std                                14.367370     2041.101896      42.724486
# min                                 1.000000      315.000000     100.000000
# 25%                                11.000000     2079.000000     140.000000
# 50%                                22.000000     3878.000000     178.000000
# 75%                                35.000000     5607.000000     212.000000
# max                                64.000000     7385.000000     248.000000

# %% [markdown]
# ### Merging: Combine Steel data with weather data

# %% [markdown]
# #### Before we merge these datasets, we have to match their style of datetimes, which will be then used as the basis of merging (connecting point)

# %%
# Step 1: remove the seconds from the steel data
# Steel data: 2023-02-20 20:56:00
# Weather data: year, month, day separately + time : 00:30 (ten minute intervals)

# remove the the seconds (2 numbers + ":")
df['End time'] = df['End time'].str[:-3]

# seems to work! steel data datetime is now e.g. 2023-02-06 01:05

# %%
df_weather.columns
# Out:
# Index(['Observation station', 'Year', 'Month', 'Day', 'Time [Local time]',
#        'Air temperature mean [°C]', 'Dew-point temperature mean [°C]',
#        'Cloud cover [1/8]', 'Air pressure mean [hPa]',
#        'Relative humidity mean [%]', 'Precipitation amount mean [mm]',
#        'Weather description', 'Horizontal visibility mean [m]'],
#       dtype='object')

# %%
# Step 2: combine all weather time information into a new variable => End time (same as in steel data)
df_weather['End time'] = df_weather['Year'].astype(str) + "-" + \
                         df_weather['Month'].astype(str).str.zfill(2) + "-" + \
                         df_weather['Day'].astype(str).str.zfill(2) + " " + \
                         df_weather['Time [Local time]'].astype(str)

# %%
# logic of the astype(str).str above:
# df_weather['Month'].astype(str) => convert this column into string
# df_weather['Month'].str.zfill(2) => use Python's string -functions (str) -> zfill

# %%
# for comparison, steel data has the time: 2023-02-06 01:05
df_weather.head(3)['End time']
# Out:
# 0    2023-01-01 00:00
# 1    2023-01-01 00:10
# 2    2023-01-01 00:20
# Name: End time, dtype: object

# %%
# Final step before merging: ROUND THE STEEL DATA minutes into the nearest tens of minutes
# basically we can make a function for pandas to fix this
# the idea: get the minutes from the time
# => round the minutes to nearest 10
# => convert minutes back to string => combine with the original time
def fix_date(row):
    date = row['End time']

    # extract te minutes only from the date
    minutes = int(date[-2:])

    # round the minutes to the nearest ten (by using negative round decimal amount)
    minutes = round(minutes, -1)

    # rebuild the date string
    # date[0:-2] => everything else except the minutes
    result = date[0:-2] + str(minutes).zfill(2)
    return result

# apply the function and check results
df['End time'] = df.apply(fix_date, axis=1)

# %%
# take a random sample to see if all time stamps
# are in the tens of minutes
df['End time'].sample(5)
# Out:
# 362111    2023-03-25 16:10
# 280859    2023-03-16 03:10
# 594017    2023-04-22 10:60
# 53623     2023-02-14 09:20
# 287589    2023-03-17 01:30
# Name: End time, dtype: object

# %% [markdown]
# #### Now we can proceed with merging the steel data and the weather

# %%
# sanity check, how much data we have BEFORE MERGING
# after merging, we should have exactly same amount of data in the end
len(df)
# Out:
# 677815

# %%
# merge data (very similar to SQL joins)
df = df.merge(df_weather, left_on="End time", right_on="End time", how="left")

# %%
# sanity check 2 => do we still have exactly same amount of data?
len(df)
# Out:
# 677815

# %%
df.columns
# Out:
# Index(['Material Type', 'End time', 'Route', 'Weight', 'Length', 'Thickness',
#        'Width', 'Grade', 'Quality Status', 'Seg No', 'Seg from', 'Seg to',
#        'CCM.TD. Heat counter Value', 'CCM.TD. Temperature liquidus Value',
#        'CCM.TD. Temperature liquidus Dynaphase Value',
#        'CCM.TD. TD internals type Value', 'CCM.TD. Slag powder Value',
#        'CCM.TD. Stopper Type Value', 'CCM.TD. Steel weight in tundish Value',
#        'CCM.TD. Tundish inflow Value', 'CCM.TD. Stopper Last Position Value',
#        'CCM.TD. Stopper position max Value',
#        'CCM.TD. Stopper position min Value',
#        'CCM.TD. Stopper pos chg max segment Value',
#        'CCM.TD. Stopper position chg 10 s Value',
#        'CCM.TD. Stopper position slab chg Value', 'CCM.TD. Superheat Value',
#        'CCM.TD. Temperature tundish Value', 'CCM.SEN. SEN Type Value',
#        'CCM.SEN. Immersion depth Value', 'CCM.MD. Level average Value',
#        'CCM.MD. Level change (max-min) Value', 'CCM.MD. Level std_dev Value',
#        'CCM.MD. Level std_dev west Value', 'CCM.MD. Level std_dev east Value',
#        'CCM.MD. Mold width Value', 'CCM.MIX. Concentration factor Value',
#        'CCM.STR. Speed - Mold avg Value', 'CCM.STR. Throughput Value',
#        'CCM.SLAB. Slab counter heat Value',
#        'CCM.SLAB. Slab counter sequence Value', 'HeatNo_in_Cast',
#        'SlabNo_in_Heat', 'CastNo', 'Observation station', 'Year', 'Month',
#        'Day', 'Time [Local time]', 'Air temperature mean [°C]',
#        'Dew-point temperature mean [°C]', 'Cloud cover [1/8]',
#        'Air pressure mean [hPa]', 'Relative humidity mean [%]',
#        'Precipitation amount mean [mm]', 'Weather description',
#        'Horizontal visibility mean [m]'],
#       dtype='object')

# %%
# we no longer need the original weather data time columns (since we have the End time)
df = df.drop(['Year', 'Month', 'Day', 'Time [Local time]',], axis=1)

# %%
len(df.columns)
# Out:
# 53

# %% [markdown]
# #### Proceed normally with fixing the steel data column format etc. as in previous examples

# %%
# let's collect all numeric columns that need their commas converted to period => float number
fixables = ["Length", 
            "Thickness",
            'CCM.TD. Steel weight in tundish Value',
            'CCM.TD. Tundish inflow Value', 'CCM.TD. Stopper Last Position Value',
            'CCM.TD. Stopper position max Value',
            'CCM.TD. Stopper position min Value',
            'CCM.TD. Stopper pos chg max segment Value',
            'CCM.TD. Stopper position chg 10 s Value',
            'CCM.TD. Stopper position slab chg Value', 
            'CCM.MD. Level average Value',
            'CCM.MD. Level change (max-min) Value', 'CCM.MD. Level std_dev Value',
            'CCM.MD. Level std_dev west Value', 'CCM.MD. Level std_dev east Value',
            'CCM.MIX. Concentration factor Value',
            'CCM.STR. Speed - Mold avg Value', 'CCM.STR. Throughput Value'
            ]

# brute force and change datatype for each of thecolumns
for column_name in fixables:
    df[column_name] = df[column_name].astype(str).replace(regex=",", value=".")
    df[column_name] = df[column_name].astype(float)

# %%
df = df.replace("-", np.nan)

# %%
df.columns
# Out:
# Index(['Material Type', 'End time', 'Route', 'Weight', 'Length', 'Thickness',
#        'Width', 'Grade', 'Quality Status', 'Seg No', 'Seg from', 'Seg to',
#        'CCM.TD. Heat counter Value', 'CCM.TD. Temperature liquidus Value',
#        'CCM.TD. Temperature liquidus Dynaphase Value',
#        'CCM.TD. TD internals type Value', 'CCM.TD. Slag powder Value',
#        'CCM.TD. Stopper Type Value', 'CCM.TD. Steel weight in tundish Value',
#        'CCM.TD. Tundish inflow Value', 'CCM.TD. Stopper Last Position Value',
#        'CCM.TD. Stopper position max Value',
#        'CCM.TD. Stopper position min Value',
#        'CCM.TD. Stopper pos chg max segment Value',
#        'CCM.TD. Stopper position chg 10 s Value',
#        'CCM.TD. Stopper position slab chg Value', 'CCM.TD. Superheat Value',
#        'CCM.TD. Temperature tundish Value', 'CCM.SEN. SEN Type Value',
#        'CCM.SEN. Immersion depth Value', 'CCM.MD. Level average Value',
#        'CCM.MD. Level change (max-min) Value', 'CCM.MD. Level std_dev Value',
#        'CCM.MD. Level std_dev west Value', 'CCM.MD. Level std_dev east Value',
#        'CCM.MD. Mold width Value', 'CCM.MIX. Concentration factor Value',
#        'CCM.STR. Speed - Mold avg Value', 'CCM.STR. Throughput Value',
#        'CCM.SLAB. Slab counter heat Value',
#        'CCM.SLAB. Slab counter sequence Value', 'HeatNo_in_Cast',
#        'SlabNo_in_Heat', 'CastNo', 'Observation station',
#        'Air temperature mean [°C]', 'Dew-point temperature mean [°C]',
#        'Cloud cover [1/8]', 'Air pressure mean [hPa]',
#        'Relative humidity mean [%]', 'Precipitation amount mean [mm]',
#        'Weather description', 'Horizontal visibility mean [m]'],
#       dtype='object')

# %%
# import dtale

# the data is now different, instead of Material Name for being a unique identifier 

# we have Cast -> Heat -> Slab -> Seg No
# One Cast usually provides ~4-8 amount of Heats, one heat usually provides 5-8 slabs
# filter_df = df[['CastNo', 'HeatNo_in_Cast', 'SlabNo_in_Heat', 'Seg No', 'CCM.TD. Steel weight in tundish Value']]
# dtale.show(filter_df).open_browser()

# %% [markdown]
# ## Before we filter only one cast/heat/slab (whatever the level), we have to process and combine the cast/heat/slab -numbers

# %%
df['CastNo'].unique()
# Out:
# array([100., 101., 102., 103., 104., 105., 106., 107., 108., 109., 110.,
#        111., 112., 113., 114., 115., 116., 117., 118., 119., 120., 121.,
#        122., 123., 124., 125., 126., 127., 128., 129., 130., 131., 132.,
#        133., 134., 135., 136., 137., 138., 139., 140., 141., 142., 143.,
#        144., 145., 146., 147., 148., 149., 150., 151., 152., 153., 154.,
#        155., 156., 157., 158., 159., 160., 161., 162., 163., 164., 165.,
#        166., 167., 168., 169., 170., 171., 172., 173., 174., 175., 176.,
#        177., 178., 179., 180., 181., 182., 183., 184., 185., 186., 187.,
#        188., 189., 190., 191., 192., 193., 194., 195., 196., 197., 198.,
#        199., 200., 201., 202., 203., 204., 205., 206., 207., 208., 209.,
#        210., 211., 212., 213., 214., 215., 216., 217., 218., 219., 220.,
#        221., 222., 223., 224., 225., 226., 227., 228., 229., 230., 231.,
#        232., 233., 234., 235., 236., 237., 238., 239., 240., 241., 242.,
#        243., 244., 245., 246., 247., 248.,  nan])

# %% [markdown]
# ### THIS IS THE PART WHERE YOU CAN CHANGE THE ACTIVE CAST VISUALIZED

# %%
# filter out only one cast at a time
# because there's too much data to visualize otherwise
selected_id = 112
df_single = df[df['CastNo'] == selected_id]
df_part = df[df['CastNo'] == selected_id]


df_single.head(3)
# Out:
#       Material Type          End time    Route  Weight  Length  Thickness  \
# 45926          slab  2023-02-12 16:10  Route 1   25796   10.65      202.0
# 45927          slab  2023-02-12 16:10  Route 1   25796   10.65      202.0
# 45928          slab  2023-02-12 16:10  Route 1   25796   10.65      202.0
#
#        Width  Grade Quality Status  Seg No  ... CastNo Observation station  \
# 45926   1539  720-1          ERROR       1  ...  112.0       Tornio Torppi
# 45927   1539  720-1          ERROR       2  ...  112.0       Tornio Torppi
# 45928   1539  720-1          ERROR       3  ...  112.0       Tornio Torppi
#
#        Air temperature mean [°C]  Dew-point temperature mean [°C]  \
# 45926                        2.4                             -0.6
# 45927                        2.4                             -0.6
# 45928                        2.4                             -0.6
#
#        Cloud cover [1/8] Air pressure mean [hPa] Relative humidity mean [%]  \
# 45926        Clear (0/8)                   999.1                         81
# 45927        Clear (0/8)                   999.1                         81
# 45928        Clear (0/8)                   999.1                         81
#
#       Precipitation amount mean [mm]     Weather description  \
# 45926                              0  No significant weather
# 45927                              0  No significant weather
# 45928                              0  No significant weather
#
#        Horizontal visibility mean [m]
# 45926                           50000
# 45927                           50000
# 45928                           50000
#
# [3 rows x 53 columns]

# %%
# for easier manipulation in future, we're going to replace the heat numbers with a more simple system
# so instead of 2205, 2170 .... we'll replace them with 1, 2, 3, 4 etc.

unique_heats = list(df_single['HeatNo_in_Cast'].unique())

# this one seems to have 4 heats (cast with id 125)
unique_heats
# Out:
# [np.int64(3843),
#  np.int64(4291),
#  np.int64(910),
#  np.int64(7133),
#  np.int64(5733),
#  np.int64(2877),
#  np.int64(2401),
#  np.int64(3836)]

# %%
# let's go through the four heat numbers
# and collect them into a dictionary
replacement_dict = {}

for heat in unique_heats:
    index = unique_heats.index(heat)
    replacement_dict[heat] = index + 1

replacement_dict
df_single['HeatNo_in_Cast'] = df_single['HeatNo_in_Cast'].map(replacement_dict)
# Out:
# C:\Users\Nihar Buha\AppData\Local\Temp\ipykernel_21044\3870752511.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_single['HeatNo_in_Cast'] = df_single['HeatNo_in_Cast'].map(replacement_dict)

# %%
# seems to work!
df_single['HeatNo_in_Cast'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %% [markdown]
# #### Sine we don't have Material Name (one id only) anymore, let's combine Cast -> Heat -> Slab -> Seg No into one single identifier

# %%
df_single['ProcessNo'] = df_single['HeatNo_in_Cast'].astype(str) + \
                         df_single['SlabNo_in_Heat'].astype(str).str.zfill(2) + \
                         df_single['Seg No'].astype(str).str.zfill(2) 


# NOTE TO SELF! SlabNo_in_Heat can be A in some rare cases
# this probably is supposed to be number 10 according to hexadecimal
df_single = df_single.reset_index()
df_single['indexno'] = df_single.index + 1
# Out:
# C:\Users\Nihar Buha\AppData\Local\Temp\ipykernel_21044\3985312939.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_single['ProcessNo'] = df_single['HeatNo_in_Cast'].astype(str) + \

# %%
# most probably a bug in matplotlib
# if you visualize data with mixed integers and floats
# the y-axis MIGHT be flipped (inverted)
df_single['Relative humidity mean [%]'] = df_single['Relative humidity mean [%]'].astype(float)
df_single['Air pressure mean [hPa]'] = df_single['Air pressure mean [hPa]'].astype(float)
df_single['Dew-point temperature mean [°C]'] = df_single['Dew-point temperature mean [°C]'].astype(float)

# %% [markdown]
# ## From this point onward, we can just visualize as previously

# %%
# phik_matrix1 = df_single.phik_matrix()

# particular_col = ['CCM.SEN. SEN Type Value',  'CCM.TD. Stopper Type Value']

# phik_subset = phik_matrix1.loc[particular_col, particular_col]

# %%
# we are going to use multi-line charts + df.melt() to visualize the process better
# see "ricebeefcoffee_revisited.ipynb" from lecture 9 examples on how to work
# with multiline + df.melt()

# list all columns you want to see in the multiline chart
columns_all = [
       'Length', 'Thickness', 'Width', 'Seg No',
       'CCM.TD. Heat counter Value',
       'CCM.TD. Temperature liquidus Value',
       'CCM.TD. Temperature liquidus Dynaphase Value',
       'CCM.TD. Steel weight in tundish Value',
       'CCM.TD. Tundish inflow Value', 'CCM.TD. Stopper Last Position Value',
       'CCM.TD. Stopper position max Value',
       'CCM.TD. Stopper position min Value',
       'CCM.TD. Stopper pos chg max segment Value',
       'CCM.TD. Stopper position chg 10 s Value',
       'CCM.TD. Stopper position slab chg Value', 'CCM.TD. Superheat Value',
       'CCM.TD. Temperature tundish Value', 
       'CCM.SEN. Immersion depth Value', 'CCM.MD. Level average Value',
       'CCM.MD. Level change (max-min) Value', 'CCM.MD. Level std_dev Value',
       'CCM.MD. Level std_dev west Value', 'CCM.MD. Level std_dev east Value',
       'CCM.MD. Mold width Value', 'CCM.MIX. Concentration factor Value',
       'CCM.STR. Speed - Mold avg Value', 'CCM.STR. Throughput Value',
       'CCM.SLAB. Slab counter heat Value',
       'CCM.SLAB. Slab counter sequence Value',
       'CCM.SEN. SEN Type Value','CCM.TD. Stopper Type Value']

# here we make more specific set of columns for easier visualization

# IF WE TRY TO VISUALIZE ALL VARIABLES AT ONCE, we can see only straight
# lines because the chart has to zoom out too much

# group of columns with very high values
columns_high = ['CCM.MD. Level average Value', 'Air pressure mean [hPa]']

# group of columns with average value ranges 
columns_middle = ['CCM.TD. Stopper Last Position Value',
       'CCM.TD. Stopper position max Value',
       'CCM.TD. Stopper position min Value',
       'CCM.TD. Steel weight in tundish Value',
       'Relative humidity mean [%]']

# group of columns with small value ranges
columns_low = ['CCM.TD. Tundish inflow Value',
               'CCM.MD. Level std_dev Value',
       'CCM.MD. Level std_dev west Value', 'CCM.MD. Level std_dev east Value', 'CCM.MIX. Concentration factor Value',
       'CCM.STR. Speed - Mold avg Value', 'CCM.STR. Throughput Value',]


# even less columns in this version with small value ranges
columns_low2 = ['CCM.TD. Tundish inflow Value',
                'CCM.MD. Level std_dev Value',
       'CCM.STR. Speed - Mold avg Value', 'CCM.STR. Throughput Value', 'Dew-point temperature mean [°C]']

columns_low3 = ['CCM.TD. Stopper Last Position Value',
       'CCM.TD. Stopper position max Value',
       'CCM.TD. Stopper position min Value',
       'CCM.TD. Steel weight in tundish Value',
       'CCM.STR. Throughput Value'
       ]

# %% [markdown]
# #### Create melt versions of some of the columns defined above

# %% [markdown]
# #### Plot the melt versions - multiline plot

# %% [markdown]
# # Perform normalization on this!!

# %%
df_single['Dew-point temperature mean [°C]'].min()
# Out:
# np.float64(-5.5)

# %%
df_single['Dew-point temperature mean [°C]'].max()
# Out:
# np.float64(-0.2)

# %%
# compare Casts 100, 125, 171 
# different stopper are in use, how does this correlate with the 
# phenomena we see in the data!
df['CCM.SEN. SEN Type Value'].value_counts()
# Out:
# CCM.SEN. SEN Type Value
# Product 1    471397
# Product 2    200963
# Name: count, dtype: int64

# %%
# it seems stopper type T1 is the most common stopper type
df['CCM.TD. Stopper Type Value'].value_counts()
# Out:
# CCM.TD. Stopper Type Value
# T1    492838
# T2    182690
# Name: count, dtype: int64

# %%
# stopper type, steel grade, SEN type ... do these correlate/associate in any way?
# does variation differ between stopper types? (e.g. is one of the types more prone
# to clogging in the long run etc.)

# %%
df
# Out:
#        Material Type          End time    Route  Weight  Length  Thickness  \
# 0               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# 1               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# 2               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# 3               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# 4               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# ...              ...               ...      ...     ...     ...        ...
# 677810          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
# 677811          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
# 677812          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
# 677813          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
# 677814          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
#
#         Width  Grade Quality Status  Seg No  ... CastNo Observation station  \
# 0        1539  720-1          ERROR       1  ...  100.0       Tornio Torppi
# 1        1539  720-1          ERROR       2  ...  100.0       Tornio Torppi
# 2        1539  720-1          ERROR       3  ...  100.0       Tornio Torppi
# 3        1539  720-1          ERROR       4  ...  100.0       Tornio Torppi
# 4        1539  720-1          ERROR       5  ...  100.0       Tornio Torppi
# ...       ...    ...            ...     ...  ...    ...                 ...
# 677810   1284  720-1          ERROR      62  ...    NaN       Tornio Torppi
# 677811   1284  720-1          ERROR      63  ...    NaN       Tornio Torppi
# 677812   1284  720-1          ERROR      64  ...    NaN       Tornio Torppi
# 677813   1284  720-1          ERROR      65  ...    NaN       Tornio Torppi
# 677814   1284  720-1          ERROR      66  ...    NaN       Tornio Torppi
#
#         Air temperature mean [°C]  Dew-point temperature mean [°C]  \
# 0                           -11.5                            -12.8
# 1                           -11.5                            -12.8
# 2                           -11.5                            -12.8
# 3                           -11.5                            -12.8
# 4                           -11.5                            -12.8
# ...                           ...                              ...
# 677810                        4.2                              2.4
# 677811                        4.2                              2.4
# 677812                        4.2                              2.4
# 677813                        4.2                              2.4
# 677814                        4.2                              2.4
#
#         Cloud cover [1/8] Air pressure mean [hPa] Relative humidity mean [%]  \
# 0             Clear (0/8)                  1023.1                         90
# 1             Clear (0/8)                  1023.1                         90
# 2             Clear (0/8)                  1023.1                         90
# 3             Clear (0/8)                  1023.1                         90
# 4             Clear (0/8)                  1023.1                         90
# ...                   ...                     ...                        ...
# 677810       Cloudy (8/8)                    1006                         88
# 677811       Cloudy (8/8)                    1006                         88
# 677812       Cloudy (8/8)                    1006                         88
# 677813       Cloudy (8/8)                    1006                         88
# 677814       Cloudy (8/8)                    1006                         88
#
#        Precipitation amount mean [mm]     Weather description  \
# 0                                   0  No significant weather
# 1                                   0  No significant weather
# 2                                   0  No significant weather
# 3                                   0  No significant weather
# 4                                   0  No significant weather
# ...                               ...                     ...
# 677810                              0             Rain, light
# 677811                              0             Rain, light
# 677812                              0             Rain, light
# 677813                              0             Rain, light
# 677814                              0             Rain, light
#
#         Horizontal visibility mean [m]
# 0                                50000
# 1                                50000
# 2                                50000
# 3                                50000
# 4                                50000
# ...                                ...
# 677810                           19478
# 677811                           19478
# 677812                           19478
# 677813                           19478
# 677814                           19478
#
# [677815 rows x 53 columns]

# %%
# # Normalization
# scaler = StandardScaler()

columns_low3 = ['CCM.TD. Stopper Last Position Value',
                'Dew-point temperature mean [°C]',
    'CCM.TD. Steel weight in tundish Value',
    'CCM.STR. Throughput Value',
    'CCM.TD. Tundish inflow Value',
    'CCM.STR. Speed - Mold avg Value',
    'CCM.TD. Stopper position slab chg Value'
    ]

# df[columns_low3] = scaler.fit_transform(df[columns_low3])

# %%
# df_single['CCM.TD. Stopper Type Value'] = df_single['CCM.TD. Stopper Type Value'].map({'T1': 0, 'T2': 1})

target_variable = 'CCM.TD. Stopper position slab chg Value'

phik_matrix = df_single.phik_matrix()

available_other_variables = [var for var in columns_all if var in phik_matrix.columns]

if target_variable in phik_matrix.index:
    correlations = phik_matrix.loc[target_variable, available_other_variables]
    print(f"Phi-K correlations of '{target_variable}' with available variables:")
    print(correlations)
else:
    print(f"Error: Target variable '{target_variable}' not found in phik_matrix index.")
# Out:
# interval columns not set, guessing: ['index', 'Weight', 'Length', 'Thickness', 'Width', 'Seg No', 'CCM.TD. Heat counter Value', 'CCM.TD. Temperature liquidus Value', 'CCM.TD. Temperature liquidus Dynaphase Value', 'CCM.TD. Stopper Type Value', 'CCM.TD. Steel weight in tundish Value', 'CCM.TD. Tundish inflow Value', 'CCM.TD. Stopper Last Position Value', 'CCM.TD. Stopper position max Value', 'CCM.TD. Stopper position min Value', 'CCM.TD. Stopper pos chg max segment Value', 'CCM.TD. Stopper position chg 10 s Value', 'CCM.TD. Stopper position slab chg Value', 'CCM.TD. Superheat Value', 'CCM.TD. Temperature tundish Value', 'CCM.SEN. Immersion depth Value', 'CCM.MD. Level average Value', 'CCM.MD. Level change (max-min) Value', 'CCM.MD. Level std_dev Value', 'CCM.MD. Level std_dev west Value', 'CCM.MD. Level std_dev east Value', 'CCM.MD. Mold width Value', 'CCM.MIX. Concentration factor Value', 'CCM.STR. Speed - Mold avg Value', 'CCM.STR. Throughput Value', 'CCM.SLAB. Slab counter heat Value', 'CCM.SLAB. Slab counter sequence Value', 'HeatNo_in_Cast', 'CastNo', 'Dew-point temperature mean [°C]', 'Air pressure mean [hPa]', 'Relative humidity mean [%]', 'indexno']
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\phik\data_quality.py:59: UserWarning: The number of unique values of variable ProcessNo is large: 4834. Are you sure this is not an interval variable? Analysis for pairs of variables including ProcessNo can be slow.
#   warnings.warn(
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\phik\data_quality.py:72: UserWarning: Not enough unique value for variable Thickness for analysis 1. Dropping this column
#   warnings.warn(
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\phik\data_quality.py:72: UserWarning: Not enough unique value for variable CCM.TD. Temperature liquidus Value for analysis 1. Dropping this column
#   warnings.warn(
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\phik\data_quality.py:72: UserWarning: Not enough unique value for variable CCM.TD. Stopper Type Value for analysis 0. Dropping this column
#   warnings.warn(
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\phik\data_quality.py:72: UserWarning: Not enough unique value for variable CastNo for analysis 1. Dropping this column
#   warnings.warn(
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\phik\data_quality.py:82: UserWarning: Not enough unique value for variable CCM.SEN. SEN Type Value for analysis 1. Dropping this column
#   warnings.warn(
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\phik\data_quality.py:82: UserWarning: Not enough unique value for variable CCM.TD. Slag powder Value for analysis 1. Dropping this column
#   warnings.warn(
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\phik\data_quality.py:82: UserWarning: Not enough unique value for variable CCM.TD. TD internals type Value for analysis 1. Dropping this column
#   warnings.warn(
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\phik\data_quality.py:82: UserWarning: Not enough unique value for variable Grade for analysis 1. Dropping this column
#   warnings.warn(
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\phik\data_quality.py:82: UserWarning: Not enough unique value for variable Material Type for analysis 1. Dropping this column
#   warnings.warn(
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\phik\data_quality.py:82: UserWarning: Not enough unique value for variable Observation station for analysis 1. Dropping this column
#   warnings.warn(
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\phik\data_quality.py:82: UserWarning: Not enough unique value for variable Precipitation amount mean [mm] for analysis 1. Dropping this column
#   warnings.warn(
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\phik\data_quality.py:82: UserWarning: Not enough unique value for variable Route for analysis 1. Dropping this column
#   warnings.warn(
# Phi-K correlations of 'CCM.TD. Stopper position slab chg Value' with available variables:
# Length                                          0.095013
# Width                                           0.470082
# Seg No                                          0.000000
# CCM.TD. Heat counter Value                      0.614813
# CCM.TD. Temperature liquidus Dynaphase Value    0.375298
# CCM.TD. Steel weight in tundish Value           0.633085
# CCM.TD. Tundish inflow Value                    0.623086
# CCM.TD. Stopper Last Position Value             0.890168
# CCM.TD. Stopper position max Value              0.902817
# CCM.TD. Stopper position min Value              0.892269
# CCM.TD. Stopper pos chg max segment Value       0.508490
# CCM.TD. Stopper position chg 10 s Value         0.525603
# CCM.TD. Stopper position slab chg Value         1.000000
# CCM.TD. Superheat Value                         0.841488
# CCM.TD. Temperature tundish Value               0.841488
# CCM.SEN. Immersion depth Value                  0.342512
# CCM.MD. Level average Value                     0.438917
# CCM.MD. Level change (max-min) Value            0.606122
# CCM.MD. Level std_dev Value                     0.629974
# CCM.MD. Level std_dev west Value                0.341743
# CCM.MD. Level std_dev east Value                0.545540
# CCM.MD. Mold width Value                        0.630945
# CCM.MIX. Concentration factor Value             0.455043
# CCM.STR. Speed - Mold avg Value                 0.562300
# CCM.STR. Throughput Value                       0.564350
# CCM.SLAB. Slab counter heat Value               0.509104
# CCM.SLAB. Slab counter sequence Value           0.884507
# Name: CCM.TD. Stopper position slab chg Value, dtype: float64

# %%
# Out:
# <Axes: >

# %%
# start_value = 1000
# end_value = 2000
# df = df[df['Seg No'] >= start_value]
# df = df[df['Seg No'] <= end_value]

# %%
# df['ProcessNo'] = df['CastNo'].astype(str) + \
df['ProcessNo'] =   df['HeatNo_in_Cast'].astype(str) + \
                        df['SlabNo_in_Heat'].astype(str).str.zfill(2) + \
                        df['Seg No'].astype(str).str.zfill(2)


df_melt_low3 = pd.melt(df, id_vars=["ProcessNo", "CastNo"], value_vars=columns_low3,
            var_name="Measurement", value_name="Value")

        # Normalizing variables to fit on the display
df_melt_low3.loc[df_melt_low3["Measurement"] == "CCM.TD. Steel weight in tundish Value", "Value"] /= 4
df_melt_low3.loc[df_melt_low3["Measurement"] == 'CCM.MD. Level change (max-min) Value', "Value"] /= 4
df_melt_low3.loc[df_melt_low3["Measurement"] == 'CCM.TD. Stopper Last Position Value', "Value"] /= 6

max_value = 10
df_melt_low3.loc[df_melt_low3["Measurement"] == "CCM.TD. Tundish inflow Value", "Value"] = np.minimum(
    df_melt_low3.loc[df_melt_low3["Measurement"] == "CCM.TD. Tundish inflow Value", "Value"], max_value
)
# Out:
# c:\Users\Nihar Buha\OneDrive\Desktop\Semester project\Project-Data-Analytics-and-Visualization\.venv\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in minimum
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df['CCM.TD. Stopper Last Position Value'] = df['CCM.TD. Stopper Last Position Value'].astype(float)
df['Dew-point temperature mean [°C]'] = df['Dew-point temperature mean [°C]'].astype(float)

# %%
cast_list = [112, 114, 129, 134]

for i in cast_list:
    
#     if i == 150.:
#         break


    df_single1 = df_melt_low3[df_melt_low3['CastNo'] == i]
    sen_type  = df.loc[df['CastNo'] == i, 'CCM.SEN. SEN Type Value']
    sen_type = sen_type.values
    sen_type = sen_type[0]
    stopper_type = df.loc[df['CastNo'] == i, 'CCM.TD. Stopper Type Value']
    stopper_type = stopper_type.values
    stopper_type = stopper_type[0]
    grade_type = df.loc[df['CastNo'] == i, 'Grade']
    grade_type = grade_type.values
    grade_type = grade_type[0]

    fig, axes = plt.subplots(figsize=(20, 8))

    plot = sns.lineplot(data=df_single1, x="ProcessNo", y="Value", hue="Measurement", errorbar=None)
    
    sns.move_legend(plot, "upper left", bbox_to_anchor=(1,1))

    # reduce the number of x-labels
    n = len(df_single) / 20
    [l.set_visible(False) for (i, l) in enumerate(plot.xaxis.get_ticklabels()) if i % n != 0]

    plt.xticks(rotation=45);


    x_min, x_max = plot.get_xlim()
    y_min, y_max = plot.get_ylim()
    plot.invert_yaxis()



    plt.text(x_max + 10, y_min + 1, f'Cast: {i}')
    plt.text(x_max + 10,y_max,f"SEN Type: {sen_type}")
    plt.text(x_max + 10, y_max -1,f"Stopper Type: {stopper_type}")
    plt.text(x_max + 10, y_max -2,f"Grade Type: {grade_type}")

    plt.tight_layout()
    plt.show()



    # filename = os.path.join('graphs/low3_graphs', f'cast_{i}.png')

    # plt.savefig(filename)

    # plt.close()

# %%
# min_val = df_single['CCM.TD. Stopper position slab chg Value'].min()
# max_val = df_single['CCM.TD. Stopper position slab chg Value'].max()

# # Min-Max scaling to [0, 1]
# df_single['x_scaled_0_1'] = (df_single['CCM.TD. Stopper position slab chg Value'] - min_val) / (max_val - min_val)

# # Scale to the range [1, 4]
# new_min = 1
# new_max = 4
# df_single['x_compressed_1_4'] = df_single['x_scaled_0_1'] * (new_max - new_min) + new_min

# ff = sns.scatterplot(x='CCM.TD. Stopper position slab chg Value', y='CCM.TD. Stopper pos chg max segment Value', hue='Quality Status', data=df_single)

# %%
# This visualization has some outliers, so to make it easier to visualize, let's get rid of 
# some of those.
df_part = df_part[df_part['CCM.MD. Level change (max-min) Value'] < 20]
df_part = df_part[df_part['CCM.TD. Stopper position slab chg Value'] < 4.5]
df_part = df_part[df_part['CCM.MD. Level change (max-min) Value'] < 9]
df_part = df_part[df_part['CCM.TD. Stopper pos chg max segment Value'] < 4.5]

# A scatter plot that shows how the QUALITY STATUS SENSOR works.

# %%
cast_list = [112, 114, 129, 134]

for i in cast_list:
    df_part = df[df['CastNo'] == i]
    # df_part = df_part[df_part['CCM.MD. Level change (max-min) Value'] < 20]
    # df_part = df_part[df_part['CCM.TD. Stopper position slab chg Value'] < 4.5]
    # df_part = df_part[df_part['CCM.MD. Level change (max-min) Value'] < 9]
    # df_part = df_part[df_part['CCM.TD. Stopper pos chg max segment Value'] < 4.5]

    sns.scatterplot(df_part, x='CCM.TD. Stopper position slab chg Value', y='CCM.MD. Level change (max-min) Value', hue='Quality Status')
    plt.show()

# %%
cast_list = [112, 114, 129, 134]

for i in cast_list:
    df_part = df[df['CastNo'] == i]
    
    plot1 =sns.countplot(x='Quality Status', data=df_part)
    # x_min, x_max = plot1.get_xlim()
    # y_min, y_max = plot1.get_ylim()
    # plt.text(x_max, y_min, f'Cast: {i}')
    plt.title(f'Cast: {i}')
    plt.show()

# %%
grouped = df_single.groupby('Grade')['CCM.TD. Stopper position slab chg Value'].mean()

grouped
# Out:
# Grade
# 720-1    2.862888
# Name: CCM.TD. Stopper position slab chg Value, dtype: float64

# %%
dfstop1 = df[df['CCM.TD. Stopper Type Value'] == 'T1']
dfstop2 = df[df['CCM.TD. Stopper Type Value'] == 'T2']
dfsen1 = df[df['CCM.TD. Stopper Type Value'] == 'Product 1']
dfsen2 = df[df['CCM.TD. Stopper Type Value'] == 'Product 2']

phik1 = dfstop1.phik_matrix()
# Out:
#        Material Type          End time    Route  Weight  Length  Thickness  \
# 0               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# 1               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# 2               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# 3               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# 4               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# ...              ...               ...      ...     ...     ...        ...
# 677810          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
# 677811          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
# 677812          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
# 677813          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
# 677814          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
#
#         Width  Grade Quality Status  Seg No  ... Observation station  \
# 0        1539  720-1          ERROR       1  ...       Tornio Torppi
# 1        1539  720-1          ERROR       2  ...       Tornio Torppi
# 2        1539  720-1          ERROR       3  ...       Tornio Torppi
# 3        1539  720-1          ERROR       4  ...       Tornio Torppi
# 4        1539  720-1          ERROR       5  ...       Tornio Torppi
# ...       ...    ...            ...     ...  ...                 ...
# 677810   1284  720-1          ERROR      62  ...       Tornio Torppi
# 677811   1284  720-1          ERROR      63  ...       Tornio Torppi
# 677812   1284  720-1          ERROR      64  ...       Tornio Torppi
# 677813   1284  720-1          ERROR      65  ...       Tornio Torppi
# 677814   1284  720-1          ERROR      66  ...       Tornio Torppi
#
#        Air temperature mean [°C]  Dew-point temperature mean [°C]  \
# 0                          -11.5                            -12.8
# 1                          -11.5                            -12.8
# 2                          -11.5                            -12.8
# 3                          -11.5                            -12.8
# 4                          -11.5                            -12.8
# ...                          ...                              ...
# 677810                       4.2                              2.4
# 677811                       4.2                              2.4
# 677812                       4.2                              2.4
# 677813                       4.2                              2.4
# 677814                       4.2                              2.4
#
#         Cloud cover [1/8]  Air pressure mean [hPa] Relative humidity mean [%]  \
# 0             Clear (0/8)                   1023.1                         90
# 1             Clear (0/8)                   1023.1                         90
# 2             Clear (0/8)                   1023.1                         90
# 3             Clear (0/8)                   1023.1                         90
# 4             Clear (0/8)                   1023.1                         90
# ...                   ...                      ...                        ...
# 677810       Cloudy (8/8)                     1006                         88
# 677811       Cloudy (8/8)                     1006                         88
# 677812       Cloudy (8/8)                     1006                         88
# 677813       Cloudy (8/8)                     1006                         88
# 677814       Cloudy (8/8)                     1006                         88
#
#        Precipitation amount mean [mm]     Weather description  \
# 0                                   0  No significant weather
# 1                                   0  No significant weather
# 2                                   0  No significant weather
# 3                                   0  No significant weather
# 4                                   0  No significant weather
# ...                               ...                     ...
# 677810                              0             Rain, light
# 677811                              0             Rain, light
# 677812                              0             Rain, light
# 677813                              0             Rain, light
# 677814                              0             Rain, light
#
#         Horizontal visibility mean [m]  ProcessNo
# 0                                50000   28210101
# 1                                50000   28210102
# 2                                50000   28210103
# 3                                50000   28210104
# 4                                50000   28210105
# ...                                ...        ...
# 677810                           19478   10500862
# 677811                           19478   10500863
# 677812                           19478   10500864
# 677813                           19478   10500865
# 677814                           19478   10500866
#
# [492838 rows x 54 columns]

# %%
df
# Out:
#        Material Type          End time    Route  Weight  Length  Thickness  \
# 0               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# 1               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# 2               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# 3               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# 4               slab  2023-02-06 01:00  Route 1   25783   10.63      202.0
# ...              ...               ...      ...     ...     ...        ...
# 677810          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
# 677811          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
# 677812          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
# 677813          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
# 677814          slab  2023-04-30 16:00  Route 1   13145    6.51      202.0
#
#         Width  Grade Quality Status  Seg No  ... Observation station  \
# 0        1539  720-1          ERROR       1  ...       Tornio Torppi
# 1        1539  720-1          ERROR       2  ...       Tornio Torppi
# 2        1539  720-1          ERROR       3  ...       Tornio Torppi
# 3        1539  720-1          ERROR       4  ...       Tornio Torppi
# 4        1539  720-1          ERROR       5  ...       Tornio Torppi
# ...       ...    ...            ...     ...  ...                 ...
# 677810   1284  720-1          ERROR      62  ...       Tornio Torppi
# 677811   1284  720-1          ERROR      63  ...       Tornio Torppi
# 677812   1284  720-1          ERROR      64  ...       Tornio Torppi
# 677813   1284  720-1          ERROR      65  ...       Tornio Torppi
# 677814   1284  720-1          ERROR      66  ...       Tornio Torppi
#
#        Air temperature mean [°C]  Dew-point temperature mean [°C]  \
# 0                          -11.5                            -12.8
# 1                          -11.5                            -12.8
# 2                          -11.5                            -12.8
# 3                          -11.5                            -12.8
# 4                          -11.5                            -12.8
# ...                          ...                              ...
# 677810                       4.2                              2.4
# 677811                       4.2                              2.4
# 677812                       4.2                              2.4
# 677813                       4.2                              2.4
# 677814                       4.2                              2.4
#
#         Cloud cover [1/8]  Air pressure mean [hPa] Relative humidity mean [%]  \
# 0             Clear (0/8)                   1023.1                         90
# 1             Clear (0/8)                   1023.1                         90
# 2             Clear (0/8)                   1023.1                         90
# 3             Clear (0/8)                   1023.1                         90
# 4             Clear (0/8)                   1023.1                         90
# ...                   ...                      ...                        ...
# 677810       Cloudy (8/8)                     1006                         88
# 677811       Cloudy (8/8)                     1006                         88
# 677812       Cloudy (8/8)                     1006                         88
# 677813       Cloudy (8/8)                     1006                         88
# 677814       Cloudy (8/8)                     1006                         88
#
#        Precipitation amount mean [mm]     Weather description  \
# 0                                   0  No significant weather
# 1                                   0  No significant weather
# 2                                   0  No significant weather
# 3                                   0  No significant weather
# 4                                   0  No significant weather
# ...                               ...                     ...
# 677810                              0             Rain, light
# 677811                              0             Rain, light
# 677812                              0             Rain, light
# 677813                              0             Rain, light
# 677814                              0             Rain, light
#
#         Horizontal visibility mean [m]  ProcessNo
# 0                                50000   28210101
# 1                                50000   28210102
# 2                                50000   28210103
# 3                                50000   28210104
# 4                                50000   28210105
# ...                                ...        ...
# 677810                           19478   10500862
# 677811                           19478   10500863
# 677812                           19478   10500864
# 677813                           19478   10500865
# 677814                           19478   10500866
#
# [677815 rows x 54 columns]

# %%
 
dfstopper1bad = df["CastNo"].isin(cast_list)

# matrix = dfstopper1bad[['CCM.TD. Stopper position slab chg Value', 'CCM.SEN. SEN Type Value', 'Grade', 'CCM.TD. Steel weight in tundish Value']].phik_matrix()
# sns.heatmap(matrix, annot=True)

dfstopper1bad
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 677810    False
# 677811    False
# 677812    False
# 677813    False
# 677814    False
# Name: CastNo, Length: 677815, dtype: bool

# %%
SEN_1 = df[df['CCM.SEN. SEN Type Value'] == 'Product 1']
SEN_2 = df[df['CCM.SEN. SEN Type Value'] == 'Product 2']
# Check connection between grade of steel and sen type? (lurking vairable?)
groupby_1 = SEN_1.groupby(['Grade'])[['CCM.SEN. SEN Type Value']].count()
groupby_1 = pd.DataFrame(groupby_1)
groupby_1.rename(columns={'CCM.SEN. SEN Type Value': 'SEN Type 1 Count'}, inplace=True)
groupby_2 = SEN_2.groupby(['Grade'])[['CCM.SEN. SEN Type Value']].count()
groupby_2 = pd.DataFrame(groupby_2)
groupby_2.rename(columns={'CCM.SEN. SEN Type Value': 'SEN Type 2 Count'}, inplace=True)
 
 
# groupby_1['CCM.SEN. SEN Type Value'] = groupby_1['SEN Type 1 Count']
# groupby_2['CCM.SEN. SEN Type Value'] = groupby_1['SEN Type 2 Count']
 
result = pd.concat([groupby_1, groupby_2], axis=1)
result = result.reset_index()
 
 
result = pd.melt(result, id_vars='Grade',
        value_vars=['SEN Type 1 Count', 'SEN Type 2 Count'],
        var_name='SEN Type', value_name='Count')
 
# result = result[result['Grade'] != '720-1']

result
# Out:
#     Grade          SEN Type     Count
# 0   720-1  SEN Type 1 Count  325824.0
# 1   720-2  SEN Type 1 Count    3221.0
# 2   720-A  SEN Type 1 Count   23756.0
# 3   720-B  SEN Type 1 Count    4716.0
# 4   720-K  SEN Type 1 Count    2028.0
# 5   724-1  SEN Type 1 Count    1091.0
# 6   724-A  SEN Type 1 Count     580.0
# 7   725-1  SEN Type 1 Count   39985.0
# 8   725-2  SEN Type 1 Count    4913.0
# 9   725-8  SEN Type 1 Count    8346.0
# 10  725-A  SEN Type 1 Count   29356.0
# 11  725-M  SEN Type 1 Count    6175.0
# 12  725-O  SEN Type 1 Count    2555.0
# 13  725-P  SEN Type 1 Count     655.0
# 14  725-U  SEN Type 1 Count   16398.0
# 15  725-Y  SEN Type 1 Count     428.0
# 16  725-Z  SEN Type 1 Count    1370.0
# 17  720-1  SEN Type 2 Count  140863.0
# 18  720-2  SEN Type 2 Count    1388.0
# 19  720-A  SEN Type 2 Count    5582.0
# 20  720-B  SEN Type 2 Count    1214.0
# 21  720-K  SEN Type 2 Count       NaN
# 22  724-1  SEN Type 2 Count     777.0
# 23  724-A  SEN Type 2 Count    1195.0
# 24  725-1  SEN Type 2 Count    8145.0
# 25  725-2  SEN Type 2 Count    5262.0
# 26  725-8  SEN Type 2 Count    7758.0
# 27  725-A  SEN Type 2 Count   17844.0
# 28  725-M  SEN Type 2 Count    1494.0
# 29  725-O  SEN Type 2 Count    3912.0
# 30  725-P  SEN Type 2 Count     696.0
# 31  725-U  SEN Type 2 Count    4833.0
# 32  725-Y  SEN Type 2 Count       NaN
# 33  725-Z  SEN Type 2 Count       NaN

# %%
fig, axes = plt.subplots(figsize=(20, 8))
sns.barplot(x='Grade', y='Count', hue='SEN Type', data=result)
# Out:
# <Axes: xlabel='Grade', ylabel='Count'>

# %%
# # Check the stopper's change value with sen type

# groupby_11 = SEN_1.groupby(['CCM.TD. Stopper position slab chg Value'])[['CCM.SEN. SEN Type Value']].count()
# groupby_11 = pd.DataFrame(groupby_11)
# groupby_11.rename(columns={'CCM.SEN. SEN Type Value': 'SEN Type 1 Count'}, inplace=True)
# groupby_22 = SEN_2.groupby(['CCM.TD. Stopper position slab chg Value'])[['CCM.SEN. SEN Type Value']].count()
# groupby_22 = pd.DataFrame(groupby_22)
# groupby_22.rename(columns={'CCM.SEN. SEN Type Value': 'SEN Type 2 Count'}, inplace=True)

# result2 = pd.concat([groupby_11, groupby_22], axis=1)
# result2 = result2.reset_index()

# result2

# result2 = pd.melt(result, id_vars='CCM.TD. Stopper position slab chg Value',
#         value_vars=['SEN Type 1 Count', 'SEN Type 2 Count'],
#         var_name='SEN Type', value_name='Count')

# %%
# fig, axes = plt.subplots(figsize=(20, 8))
# sns.barplot(x='CCM.TD. Stopper position slab chg Value', y='Count', hue='SEN Type', data=result2)

# %%
 
for cast_id in range(99, 247):
        df_single = df[df['CastNo'] == cast_id]
        print(f"CastNo {cast_id} Quality Status Counts:")
        print(df_single['Quality Status'].value_counts())
        # print(df_single['End time'])
# Out:
# CastNo 99 Quality Status Counts:
# Series([], Name: count, dtype: int64)
# CastNo 100 Quality Status Counts:
# Quality Status
# OK         338
# ERROR      107
# WARNING    107
# Name: count, dtype: int64
# CastNo 101 Quality Status Counts:
# Quality Status
# OK         270
# WARNING    163
# ERROR      107
# Name: count, dtype: int64
# CastNo 102 Quality Status Counts:
# Quality Status
# OK         2449
# WARNING    1391
# ERROR       497
# Name: count, dtype: int64
# CastNo 103 Quality Status Counts:
# Quality Status
# OK         3589
# WARNING     665
# ERROR       116
# Name: count, dtype: int64
# CastNo 104 Quality Status Counts:
# Quality Status
# OK         4292
# WARNING    1476
# ERROR       116
# Name: count, dtype: int64
# CastNo 105 Quality Status Counts:
# Quality Status
# OK         3729
# WARNING     922
# ERROR       416
# Name: count, dtype: int64
# CastNo 106 Quality Status Counts:
# Quality Status
# OK         3424
# WARNING    1035
# ERROR       428
# Name: count, dtype: int64
# CastNo 107 Quality Status Counts:
# Quality Status
# OK         2426
# WARNING    1019
# ERROR       628
# Name: count, dtype: int64
# CastNo 108 Quality Status Counts:
# Quality Status
# ERROR      2418
# OK         1566
# WARNING     854
# Name: count, dtype: int64
# CastNo 109 Quality Status Counts:
# Quality Status
# OK         2864
# WARNING    1579
# ERROR      1201
# Name: count, dtype: int64
# CastNo 110 Quality Status Counts:
# Quality Status
# OK         2534
# WARNING     692
# ERROR       344
# Name: count, dtype: int64
# CastNo 111 Quality Status Counts:
# Quality Status
# OK         1212
# WARNING     555
# ERROR       397
# Name: count, dtype: int64
# CastNo 112 Quality Status Counts:
# Quality Status
# ERROR      2203
# WARNING    1561
# OK         1070
# Name: count, dtype: int64
# CastNo 113 Quality Status Counts:
# Quality Status
# OK         4806
# WARNING     797
# ERROR       342
# Name: count, dtype: int64
# CastNo 114 Quality Status Counts:
# Quality Status
# OK         3342
# WARNING    1735
# ERROR      1462
# Name: count, dtype: int64
# CastNo 115 Quality Status Counts:
# Quality Status
# OK         3909
# WARNING     815
# ERROR       107
# Name: count, dtype: int64
# CastNo 116 Quality Status Counts:
# Quality Status
# OK         2318
# WARNING    1144
# ERROR       107
# Name: count, dtype: int64
# CastNo 117 Quality Status Counts:
# Quality Status
# OK         2942
# WARNING    1373
# ERROR       317
# Name: count, dtype: int64
# CastNo 118 Quality Status Counts:
# Quality Status
# OK       1776
# ERROR     414
# Name: count, dtype: int64
# CastNo 119 Quality Status Counts:
# Quality Status
# OK         2801
# WARNING     639
# ERROR       101
# Name: count, dtype: int64
# CastNo 120 Quality Status Counts:
# Quality Status
# OK         4051
# WARNING     580
# ERROR       107
# Name: count, dtype: int64
# CastNo 121 Quality Status Counts:
# Quality Status
# OK         4696
# WARNING     988
# ERROR       116
# Name: count, dtype: int64
# CastNo 122 Quality Status Counts:
# Quality Status
# OK         6612
# ERROR       440
# WARNING     348
# Name: count, dtype: int64
# CastNo 123 Quality Status Counts:
# Quality Status
# OK         4187
# WARNING     483
# ERROR       101
# Name: count, dtype: int64
# CastNo 124 Quality Status Counts:
# Quality Status
# OK         511
# ERROR      107
# WARNING    107
# Name: count, dtype: int64
# CastNo 125 Quality Status Counts:
# Quality Status
# OK         1793
# WARNING     400
# ERROR       107
# Name: count, dtype: int64
# CastNo 126 Quality Status Counts:
# Quality Status
# OK         1284
# WARNING     294
# ERROR       107
# Name: count, dtype: int64
# CastNo 127 Quality Status Counts:
# Quality Status
# OK         3265
# WARNING    1341
# ERROR       107
# Name: count, dtype: int64
# CastNo 128 Quality Status Counts:
# Quality Status
# OK         4825
# WARNING     880
# ERROR       116
# Name: count, dtype: int64
# CastNo 129 Quality Status Counts:
# Quality Status
# OK         3499
# WARNING    1009
# ERROR       426
# Name: count, dtype: int64
# CastNo 130 Quality Status Counts:
# Quality Status
# OK         5402
# WARNING     418
# ERROR       110
# Name: count, dtype: int64
# CastNo 131 Quality Status Counts:
# Quality Status
# OK         3559
# ERROR       847
# WARNING     374
# Name: count, dtype: int64
# CastNo 132 Quality Status Counts:
# Quality Status
# OK         3471
# WARNING     895
# ERROR       312
# Name: count, dtype: int64
# CastNo 133 Quality Status Counts:
# Quality Status
# OK         4756
# WARNING     822
# ERROR       116
# Name: count, dtype: int64
# CastNo 134 Quality Status Counts:
# Quality Status
# OK         6026
# WARNING     899
# ERROR       197
# Name: count, dtype: int64
# CastNo 135 Quality Status Counts:
# Quality Status
# OK         3097
# WARNING     182
# ERROR       107
# Name: count, dtype: int64
# CastNo 136 Quality Status Counts:
# Quality Status
# OK         1605
# WARNING     705
# ERROR       107
# Name: count, dtype: int64
# CastNo 137 Quality Status Counts:
# Quality Status
# OK         3907
# WARNING     699
# ERROR       214
# Name: count, dtype: int64
# CastNo 138 Quality Status Counts:
# Quality Status
# ERROR      212
# OK         210
# WARNING    162
# Name: count, dtype: int64
# CastNo 139 Quality Status Counts:
# Quality Status
# OK         2671
# ERROR       420
# WARNING     382
# Name: count, dtype: int64
# CastNo 140 Quality Status Counts:
# Quality Status
# OK         3424
# WARNING    1176
# ERROR       262
# Name: count, dtype: int64
# CastNo 141 Quality Status Counts:
# Quality Status
# OK         4985
# WARNING     648
# ERROR       113
# Name: count, dtype: int64
# CastNo 142 Quality Status Counts:
# Quality Status
# OK         6683
# WARNING     303
# ERROR       232
# Name: count, dtype: int64
# CastNo 143 Quality Status Counts:
# Quality Status
# OK         3807
# WARNING     811
# ERROR       107
# Name: count, dtype: int64
# CastNo 144 Quality Status Counts:
# Quality Status
# OK         3824
# WARNING     787
# ERROR       101
# Name: count, dtype: int64
# CastNo 145 Quality Status Counts:
# Quality Status
# OK         4566
# WARNING     970
# ERROR       113
# Name: count, dtype: int64
# CastNo 146 Quality Status Counts:
# Quality Status
# OK         1791
# WARNING     226
# ERROR       173
# Name: count, dtype: int64
# CastNo 147 Quality Status Counts:
# Quality Status
# OK         5228
# WARNING     189
# ERROR       116
# Name: count, dtype: int64
# CastNo 148 Quality Status Counts:
# Quality Status
# OK         3676
# WARNING     909
# ERROR       107
# Name: count, dtype: int64
# CastNo 149 Quality Status Counts:
# Quality Status
# OK         1465
# WARNING     764
# ERROR       101
# Name: count, dtype: int64
# CastNo 150 Quality Status Counts:
# Quality Status
# OK         1676
# WARNING     466
# ERROR       198
# Name: count, dtype: int64
# CastNo 151 Quality Status Counts:
# Quality Status
# OK         4743
# WARNING     542
# ERROR       217
# Name: count, dtype: int64
# CastNo 152 Quality Status Counts:
# Quality Status
# OK         6853
# WARNING     232
# ERROR       185
# Name: count, dtype: int64
# CastNo 153 Quality Status Counts:
# Quality Status
# OK         3050
# WARNING    1453
# ERROR       202
# Name: count, dtype: int64
# CastNo 154 Quality Status Counts:
# Quality Status
# OK         3594
# WARNING     931
# ERROR       214
# Name: count, dtype: int64
# CastNo 155 Quality Status Counts:
# Quality Status
# OK         3415
# WARNING    1813
# ERROR       526
# Name: count, dtype: int64
# CastNo 156 Quality Status Counts:
# Quality Status
# OK         4616
# WARNING     925
# ERROR       287
# Name: count, dtype: int64
# CastNo 157 Quality Status Counts:
# Quality Status
# OK         3197
# WARNING    1273
# ERROR       202
# Name: count, dtype: int64
# CastNo 158 Quality Status Counts:
# Quality Status
# OK         4027
# WARNING     709
# ERROR       107
# Name: count, dtype: int64
# CastNo 159 Quality Status Counts:
# Quality Status
# OK         4720
# WARNING     230
# ERROR       191
# Name: count, dtype: int64
# CastNo 160 Quality Status Counts:
# Quality Status
# OK         1102
# WARNING     768
# ERROR       207
# Name: count, dtype: int64
# CastNo 161 Quality Status Counts:
# Quality Status
# OK         2896
# WARNING     341
# ERROR       166
# Name: count, dtype: int64
# CastNo 162 Quality Status Counts:
# Quality Status
# OK         3023
# WARNING     232
# ERROR       181
# Name: count, dtype: int64
# CastNo 163 Quality Status Counts:
# Quality Status
# OK         4003
# WARNING    1501
# ERROR       311
# Name: count, dtype: int64
# CastNo 164 Quality Status Counts:
# Quality Status
# OK         4010
# WARNING     801
# ERROR       107
# Name: count, dtype: int64
# CastNo 165 Quality Status Counts:
# Quality Status
# OK         3444
# WARNING     589
# ERROR       107
# Name: count, dtype: int64
# CastNo 166 Quality Status Counts:
# Quality Status
# OK         3103
# WARNING     493
# ERROR       107
# Name: count, dtype: int64
# CastNo 167 Quality Status Counts:
# Quality Status
# OK         642
# WARNING    321
# ERROR      107
# Name: count, dtype: int64
# CastNo 168 Quality Status Counts:
# Quality Status
# OK         4483
# WARNING    1107
# ERROR       191
# Name: count, dtype: int64
# CastNo 169 Quality Status Counts:
# Quality Status
# ERROR    194
# OK       148
# Name: count, dtype: int64
# CastNo 170 Quality Status Counts:
# Quality Status
# OK         1044
# WARNING     232
# ERROR       189
# Name: count, dtype: int64
# CastNo 171 Quality Status Counts:
# Quality Status
# OK         2530
# WARNING     690
# ERROR       291
# Name: count, dtype: int64
# CastNo 172 Quality Status Counts:
# Quality Status
# OK         2423
# WARNING     394
# ERROR       214
# Name: count, dtype: int64
# CastNo 173 Quality Status Counts:
# Quality Status
# OK         2889
# WARNING     603
# ERROR       107
# Name: count, dtype: int64
# CastNo 174 Quality Status Counts:
# Quality Status
# OK         3799
# WARNING     912
# ERROR       107
# Name: count, dtype: int64
# CastNo 175 Quality Status Counts:
# Quality Status
# OK         4628
# WARNING     329
# ERROR       182
# Name: count, dtype: int64
# CastNo 176 Quality Status Counts:
# Quality Status
# OK         5127
# WARNING    1152
# ERROR       320
# Name: count, dtype: int64
# CastNo 177 Quality Status Counts:
# Quality Status
# OK         4968
# WARNING     873
# ERROR       178
# Name: count, dtype: int64
# CastNo 178 Quality Status Counts:
# Quality Status
# OK         6148
# ERROR       696
# WARNING     464
# Name: count, dtype: int64
# CastNo 179 Quality Status Counts:
# Quality Status
# OK         4064
# WARNING     623
# ERROR       214
# Name: count, dtype: int64
# CastNo 180 Quality Status Counts:
# Quality Status
# OK         4482
# WARNING    1160
# ERROR       190
# Name: count, dtype: int64
# CastNo 181 Quality Status Counts:
# Quality Status
# ERROR    60
# Name: count, dtype: int64
# CastNo 182 Quality Status Counts:
# Quality Status
# OK         4780
# WARNING     580
# ERROR       401
# Name: count, dtype: int64
# CastNo 183 Quality Status Counts:
# Quality Status
# OK         4859
# WARNING     566
# ERROR       178
# Name: count, dtype: int64
# CastNo 184 Quality Status Counts:
# Quality Status
# OK         3919
# WARNING     158
# ERROR       107
# Name: count, dtype: int64
# CastNo 185 Quality Status Counts:
# Quality Status
# OK         3226
# WARNING    1248
# ERROR       212
# Name: count, dtype: int64
# CastNo 186 Quality Status Counts:
# Quality Status
# OK         2984
# WARNING    1599
# ERROR       214
# Name: count, dtype: int64
# CastNo 187 Quality Status Counts:
# Quality Status
# OK         4675
# WARNING     965
# ERROR       176
# Name: count, dtype: int64
# CastNo 188 Quality Status Counts:
# Quality Status
# OK         5364
# WARNING     222
# ERROR       192
# Name: count, dtype: int64
# CastNo 189 Quality Status Counts:
# Quality Status
# OK         3638
# WARNING    1052
# ERROR       214
# Name: count, dtype: int64
# CastNo 190 Quality Status Counts:
# Quality Status
# OK         1971
# WARNING     427
# ERROR       321
# Name: count, dtype: int64
# CastNo 191 Quality Status Counts:
# Quality Status
# OK         1648
# WARNING     589
# ERROR       107
# Name: count, dtype: int64
# CastNo 192 Quality Status Counts:
# Quality Status
# OK         2782
# ERROR      1030
# WARNING     428
# Name: count, dtype: int64
# CastNo 193 Quality Status Counts:
# Quality Status
# OK         4169
# WARNING    1276
# ERROR       299
# Name: count, dtype: int64
# CastNo 194 Quality Status Counts:
# Quality Status
# OK         4230
# WARNING     594
# ERROR       107
# Name: count, dtype: int64
# CastNo 195 Quality Status Counts:
# Quality Status
# OK         3487
# ERROR       745
# WARNING     634
# Name: count, dtype: int64
# CastNo 196 Quality Status Counts:
# Quality Status
# OK         5052
# WARNING     339
# ERROR       328
# Name: count, dtype: int64
# CastNo 197 Quality Status Counts:
# Quality Status
# OK         4929
# WARNING     226
# ERROR       183
# Name: count, dtype: int64
# CastNo 198 Quality Status Counts:
# Quality Status
# OK         4065
# WARNING     513
# ERROR       105
# Name: count, dtype: int64
# CastNo 199 Quality Status Counts:
# Quality Status
# OK         5266
# WARNING     348
# ERROR       221
# Name: count, dtype: int64
# CastNo 200 Quality Status Counts:
# Quality Status
# OK         4320
# WARNING     392
# ERROR       105
# Name: count, dtype: int64
# CastNo 201 Quality Status Counts:
# Quality Status
# OK         5309
# WARNING     601
# ERROR       214
# Name: count, dtype: int64
# CastNo 202 Quality Status Counts:
# Quality Status
# OK         3168
# WARNING    1566
# ERROR       105
# Name: count, dtype: int64
# CastNo 203 Quality Status Counts:
# Quality Status
# OK         5560
# WARNING     232
# ERROR       190
# Name: count, dtype: int64
# CastNo 204 Quality Status Counts:
# Quality Status
# OK         5265
# WARNING     265
# ERROR       114
# Name: count, dtype: int64
# CastNo 205 Quality Status Counts:
# Quality Status
# OK         4018
# WARNING     749
# ERROR       273
# Name: count, dtype: int64
# CastNo 206 Quality Status Counts:
# Quality Status
# OK         4819
# WARNING     681
# ERROR       301
# Name: count, dtype: int64
# CastNo 207 Quality Status Counts:
# Quality Status
# OK         4428
# WARNING    1077
# ERROR       428
# Name: count, dtype: int64
# CastNo 208 Quality Status Counts:
# Quality Status
# OK         2925
# WARNING     490
# ERROR       107
# Name: count, dtype: int64
# CastNo 209 Quality Status Counts:
# Quality Status
# OK         916
# WARNING    167
# ERROR      107
# Name: count, dtype: int64
# CastNo 210 Quality Status Counts:
# Quality Status
# OK         4597
# WARNING     318
# ERROR       101
# Name: count, dtype: int64
# CastNo 211 Quality Status Counts:
# Quality Status
# OK         5328
# WARNING     458
# ERROR       295
# Name: count, dtype: int64
# CastNo 212 Quality Status Counts:
# Quality Status
# OK         4028
# ERROR       535
# WARNING     496
# Name: count, dtype: int64
# CastNo 213 Quality Status Counts:
# Quality Status
# OK         5591
# WARNING     229
# ERROR       178
# Name: count, dtype: int64
# CastNo 214 Quality Status Counts:
# Quality Status
# OK         4138
# WARNING     696
# ERROR       310
# Name: count, dtype: int64
# CastNo 215 Quality Status Counts:
# Quality Status
# OK         2521
# WARNING     378
# ERROR       101
# Name: count, dtype: int64
# CastNo 216 Quality Status Counts:
# Quality Status
# OK         1381
# WARNING     276
# ERROR       107
# Name: count, dtype: int64
# CastNo 217 Quality Status Counts:
# Quality Status
# OK         3120
# WARNING     348
# ERROR       177
# Name: count, dtype: int64
# CastNo 218 Quality Status Counts:
# Quality Status
# OK         731
# WARNING    450
# ERROR      179
# Name: count, dtype: int64
# CastNo 219 Quality Status Counts:
# Quality Status
# OK         4875
# WARNING     755
# ERROR       399
# Name: count, dtype: int64
# CastNo 220 Quality Status Counts:
# Quality Status
# OK         3258
# WARNING     813
# ERROR       107
# Name: count, dtype: int64
# CastNo 221 Quality Status Counts:
# Quality Status
# OK         3897
# WARNING     632
# ERROR       315
# Name: count, dtype: int64
# CastNo 222 Quality Status Counts:
# Quality Status
# OK         3905
# WARNING    1846
# ERROR       290
# Name: count, dtype: int64
# CastNo 223 Quality Status Counts:
# Quality Status
# OK         3873
# WARNING     810
# ERROR       411
# Name: count, dtype: int64
# CastNo 224 Quality Status Counts:
# Quality Status
# OK         4264
# WARNING     416
# ERROR       107
# Name: count, dtype: int64
# CastNo 225 Quality Status Counts:
# Quality Status
# OK         4853
# WARNING     923
# ERROR       183
# Name: count, dtype: int64
# CastNo 226 Quality Status Counts:
# Quality Status
# OK         5313
# ERROR       296
# WARNING     231
# Name: count, dtype: int64
# CastNo 227 Quality Status Counts:
# Quality Status
# OK         3709
# WARNING     927
# ERROR       107
# Name: count, dtype: int64
# CastNo 228 Quality Status Counts:
# Quality Status
# OK         5392
# WARNING     290
# ERROR       116
# Name: count, dtype: int64
# CastNo 229 Quality Status Counts:
# Quality Status
# OK         2001
# WARNING     289
# ERROR       107
# Name: count, dtype: int64
# CastNo 230 Quality Status Counts:
# Quality Status
# OK         2996
# WARNING     677
# ERROR       106
# Name: count, dtype: int64
# CastNo 231 Quality Status Counts:
# Quality Status
# OK         3386
# WARNING    1353
# ERROR       428
# Name: count, dtype: int64
# CastNo 232 Quality Status Counts:
# Quality Status
# OK         4809
# ERROR       107
# WARNING      74
# Name: count, dtype: int64
# CastNo 233 Quality Status Counts:
# Quality Status
# OK         5021
# WARNING     696
# ERROR       198
# Name: count, dtype: int64
# CastNo 234 Quality Status Counts:
# Quality Status
# OK         5388
# WARNING     348
# ERROR       302
# Name: count, dtype: int64
# CastNo 235 Quality Status Counts:
# Quality Status
# OK         2645
# WARNING     575
# ERROR       361
# Name: count, dtype: int64
# CastNo 236 Quality Status Counts:
# Quality Status
# OK         1727
# WARNING     399
# ERROR       115
# Name: count, dtype: int64
# CastNo 237 Quality Status Counts:
# Quality Status
# OK         4500
# WARNING     278
# ERROR       107
# Name: count, dtype: int64
# CastNo 238 Quality Status Counts:
# Quality Status
# OK         4066
# WARNING     709
# ERROR       214
# Name: count, dtype: int64
# CastNo 239 Quality Status Counts:
# Quality Status
# OK         4815
# WARNING     689
# ERROR       213
# Name: count, dtype: int64
# CastNo 240 Quality Status Counts:
# Quality Status
# OK         3131
# WARNING    1392
# ERROR      1149
# Name: count, dtype: int64
# CastNo 241 Quality Status Counts:
# Quality Status
# OK         2395
# WARNING     483
# ERROR       101
# Name: count, dtype: int64
# CastNo 242 Quality Status Counts:
# Quality Status
# OK         856
# WARNING    192
# ERROR      107
# Name: count, dtype: int64
# CastNo 243 Quality Status Counts:
# Quality Status
# OK         4556
# WARNING     169
# ERROR       107
# Name: count, dtype: int64
# CastNo 244 Quality Status Counts:
# Quality Status
# OK         2442
# WARNING    1269
# ERROR       585
# Name: count, dtype: int64
# CastNo 245 Quality Status Counts:
# Quality Status
# OK         3166
# WARNING    1946
# ERROR       798
# Name: count, dtype: int64
# CastNo 246 Quality Status Counts:
# Quality Status
# OK         3881
# WARNING    1621
# ERROR       400
# Name: count, dtype: int64
