# %% [markdown]
# ### NOTES UP HERE:

# %% [markdown]
# - This is a TIMESERIES dataframe. Possibly, sample the data into different heats. From beginning to end.
# - For heat correlations, Phik-matrix use recommended by Tuomas
# - pd.melt
# - to rotate the x-axis labels: plt.xticks(rotation=45); (the ; at the end important)
# - Weather data
# - Steel production, how much does the weather effect it?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandasgui import show

# %%
df = pd.read_csv('../data/sulatto_fulldata2025_version2.csv', delimiter=";", index_col=None)
# Out:
# C:\Users\kalle\AppData\Local\Temp\ipykernel_1300\1320071282.py:1: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/sulatto_fulldata2025_version2.csv', delimiter=";", index_col=None)

# %%
#show(df)

# %%
df
# Out:
#        Material Type             End time    Route  Weight Length Thickness  \
# 0               slab  2023-02-06 01:05:11  Route 1   25783  10,63   202,000
# 1               slab  2023-02-06 01:05:11  Route 1   25783  10,63   202,000
# 2               slab  2023-02-06 01:05:11  Route 1   25783  10,63   202,000
# 3               slab  2023-02-06 01:05:11  Route 1   25783  10,63   202,000
# 4               slab  2023-02-06 01:05:11  Route 1   25783  10,63   202,000
# ...              ...                  ...      ...     ...    ...       ...
# 677810          slab  2023-04-30 16:03:14  Route 1   13145   6,51   202,000
# 677811          slab  2023-04-30 16:03:14  Route 1   13145   6,51   202,000
# 677812          slab  2023-04-30 16:03:14  Route 1   13145   6,51   202,000
# 677813          slab  2023-04-30 16:03:14  Route 1   13145   6,51   202,000
# 677814          slab  2023-04-30 16:03:14  Route 1   13145   6,51   202,000
#
#         Width  Grade Quality Status  Seg No  ...  \
# 0        1539  720-1          ERROR       1  ...
# 1        1539  720-1          ERROR       2  ...
# 2        1539  720-1          ERROR       3  ...
# 3        1539  720-1          ERROR       4  ...
# 4        1539  720-1          ERROR       5  ...
# ...       ...    ...            ...     ...  ...
# 677810   1284  720-1          ERROR      62  ...
# 677811   1284  720-1          ERROR      63  ...
# 677812   1284  720-1          ERROR      64  ...
# 677813   1284  720-1          ERROR      65  ...
# 677814   1284  720-1          ERROR      66  ...
#
#        CCM.MD. Level std_dev east Value CCM.MD. Mold width Value  \
# 0                                 12,50                   1539.0
# 1                                 12,50                   1539.0
# 2                                 12,50                   1539.0
# 3                                 12,50                   1539.0
# 4                                 12,50                   1539.0
# ...                                 ...                      ...
# 677810                             5,50                   1284.0
# 677811                             5,50                   1284.0
# 677812                             5,50                   1284.0
# 677813                             5,50                   1284.0
# 677814                             5,50                   1284.0
#
#         CCM.MIX. Concentration factor Value  CCM.STR. Speed - Mold avg Value  \
# 0                                     0,000                             0,50
# 1                                     0,000                             0,54
# 2                                     0,000                             0,56
# 3                                     0,000                             0,57
# 4                                     0,000                             0,59
# ...                                     ...                              ...
# 677810                                0,000                             0,30
# 677811                                0,000                             0,27
# 677812                                0,000                             0,26
# 677813                                0,000                             0,24
# 677814                                0,000                             0,24
#
#         CCM.STR. Throughput Value CCM.SLAB. Slab counter heat Value  \
# 0                            1,18                               1.0
# 1                            1,28                               1.0
# 2                            1,33                               1.0
# 3                            1,37                               1.0
# 4                            1,41                               1.0
# ...                           ...                               ...
# 677810                       0,64                               8.0
# 677811                       0,56                               8.0
# 677812                       0,51                               8.0
# 677813                       0,45                               8.0
# 677814                       0,45                               8.0
#
#        CCM.SLAB. Slab counter sequence Value HeatNo_in_Cast SlabNo_in_Heat  \
# 0                                        1.0           2821              1
# 1                                        1.0           2821              1
# 2                                        1.0           2821              1
# 3                                        1.0           2821              1
# 4                                        1.0           2821              1
# ...                                      ...            ...            ...
# 677810                                  53.0           1050              8
# 677811                                  53.0           1050              8
# 677812                                  53.0           1050              8
# 677813                                  53.0           1050              8
# 677814                                  53.0           1050              8
#
#        CastNo
# 0       100.0
# 1       100.0
# 2       100.0
# 3       100.0
# 4       100.0
# ...       ...
# 677810    NaN
# 677811    NaN
# 677812    NaN
# 677813    NaN
# 677814    NaN
#
# [677815 rows x 44 columns]

# %%
df['Route'].nunique()
# This can be dropped
# Out:
# 1

# %%
df['CCM.MIX. Concentration factor Value'].nunique()
# Out:
# 1001

# %%
df['Weight'].nunique()
# Out:
# 1079

# %%
df['Thickness'].nunique()
# Can be dropped
# Out:
# 1

# %%
df['Length'].nunique()
# Out:
# 268

# %%
df['Width'].nunique()
# Out:
# 37

# %% [markdown]
# COMMAS INTO DOTS

# %%
df['Length'] = df['Length'].str.replace(',','.')
df['Thickness'] = df['Thickness'].str.replace(',','.')
df['CCM.TD. Steel weight in tundish Value'] = df['CCM.TD. Steel weight in tundish Value'].str.replace(',','.')
df['CCM.STR. Speed - Mold avg Value'] = df['CCM.STR. Speed - Mold avg Value'].str.replace(',','.')

# %% [markdown]
# We could maybe use Thickness * Length * Width to calculate Volume of slabs, to reduce the amount of columns.

# %%
df['Width'] = df['Width'].astype(float) / 1000
df['Thickness'] = df['Thickness'].astype(float) / 1000

df['Slab_volume^m3'] = df['Width'].astype(float) * df['Length'].astype(float) * df['Thickness'].astype(float)
df['Slab_volume^m3'] = df['Slab_volume^m3'].round(2)

# %%
df['Slab_density'] = df['Weight'] / df['Slab_volume^m3']

# %%
df['Material Type'].value_counts()
# Out:
# Material Type
# slab    677815
# Name: count, dtype: int64

# %%
df['CCM.TD. Heat counter Value'].value_counts()
# Out:
# CCM.TD. Heat counter Value
# 1.0     97364
# 2.0     94453
# 3.0     94178
# 4.0     89181
# 5.0     83450
# 6.0     78774
# 7.0     72487
# 8.0     64651
# 9.0      2094
# 10.0      667
# Name: count, dtype: int64

# %% [markdown]
# DROPS HERE

# %%
df = df.drop('CCM.TD. Slag powder Value', axis=1)
df = df.drop('CCM.TD. TD internals type Value', axis=1)
df = df.drop('Route', axis=1)
df = df.drop('Width', axis=1)
df = df.drop('Thickness', axis=1)
df = df.drop('Length', axis=1)
df = df.drop('Material Type', axis=1)
# df = df.drop('SlabNo_in_Heat', axis=1) maybe drop this? it'not in data header explanation

# %%
df['SlabNo_in_Heat'].value_counts()
# Out:
# SlabNo_in_Heat
# 3    103909
# 1    103869
# 2    103774
# 4    103052
# 5    101168
# 6     81821
# 7     26115
# 2      7849
# 3      7783
# 1      7779
# 4      7734
# 5      7519
# 6      6214
# 8      4193
# 7      2475
# 8      1264
# 9       762
# 9       303
# A       232
# Name: count, dtype: int64

# %%
df['CCM.TD. Steel weight in tundish Value'].nunique()
# Out:
# 240

# %%
df['CCM.TD. Tundish inflow Value'].nunique()
# Out:
# 1533

# %%
df['CCM.TD. Stopper Last Position Value'].nunique()
# Out:
# 534

# %%
df['CCM.TD. Stopper position min Value'].nunique()
# Out:
# 548

# %%
df['CCM.TD. Stopper pos chg max segment Value'].nunique()
# Out:
# 137

# %%
df['CCM.TD. Stopper position chg 10 s Value'].nunique()
# Out:
# 103

# %%
df['CCM.SEN. SEN Type Value'].value_counts()
# Out:
# CCM.SEN. SEN Type Value
# Product 1    471397
# Product 2    200963
# Name: count, dtype: int64

# %%
data1 = df.corr(numeric_only=True)

# %%
plt.figure(figsize=(11, 9))
sns.heatmap(data1, annot=True, linewidths=1)
# Out:
# <Axes: >

# %%
df["CCM.TD. Temperature liquidus Value"].value_counts()
# Out:
# CCM.TD. Temperature liquidus Value
# 1455.0    677299
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# End time                                           0
# Weight                                             0
# Grade                                              0
# Quality Status                                     0
# Seg No                                             0
# Seg from                                           0
# Seg to                                             0
# CCM.TD. Heat counter Value                       516
# CCM.TD. Temperature liquidus Value               516
# CCM.TD. Temperature liquidus Dynaphase Value     516
# CCM.TD. Stopper Type Value                      2287
# CCM.TD. Steel weight in tundish Value            516
# CCM.TD. Tundish inflow Value                    1184
# CCM.TD. Stopper Last Position Value              516
# CCM.TD. Stopper position max Value               516
# CCM.TD. Stopper position min Value               516
# CCM.TD. Stopper pos chg max segment Value        516
# CCM.TD. Stopper position chg 10 s Value          516
# CCM.TD. Stopper position slab chg Value          516
# CCM.TD. Superheat Value                          516
# CCM.TD. Temperature tundish Value                516
# CCM.SEN. SEN Type Value                         5455
# CCM.SEN. Immersion depth Value                   516
# CCM.MD. Level average Value                      516
# CCM.MD. Level change (max-min) Value             516
# CCM.MD. Level std_dev Value                      516
# CCM.MD. Level std_dev west Value                 516
# CCM.MD. Level std_dev east Value                 516
# CCM.MD. Mold width Value                         516
# CCM.MIX. Concentration factor Value              553
# CCM.STR. Speed - Mold avg Value                  516
# CCM.STR. Throughput Value                        516
# CCM.SLAB. Slab counter heat Value               3551
# CCM.SLAB. Slab counter sequence Value           3319
# HeatNo_in_Cast                                     0
# SlabNo_in_Heat                                     0
# CastNo                                          5989
# Slab_volume^m3                                     0
# Slab_density                                       0
# dtype: int64

# %%
df['Quality Status'].value_counts()
# Out:
# Quality Status
# OK         531731
# WARNING    103772
# ERROR       42312
# Name: count, dtype: int64
